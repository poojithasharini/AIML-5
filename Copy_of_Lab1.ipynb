# %% [markdown]
# <a href="https://colab.research.google.com/github/poojithasharini/AIML-5/blob/main/Copy_of_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
list1=[1,2,3]
array1 = np.array(list1)
array1
# Out:
# array([1, 2, 3])

# %%
type(list1)
# Out:
# list

# %%
type(array1)
# Out:
# numpy.ndarray

# %%
list2=[3,2,1]
array2=np.array(list2)
array2
# Out:
# array([3, 2, 1])

# %%
print("array2 multiplied by array1: ",array1*array2)
print("array2 divided by array1: ", array1/array2)
print("array2 raised to the power of array1: ", array1**array2)
print(f"{array2} raised to the power of {array1}: , {array2**array1}")
# Out:
# array2 multiplied by array1:  [3 4 3]
# array2 divided by array1:  [0.33333333 1.         3.        ]
# array2 raised to the power of array1:  [1 4 3]
# [3 2 1] raised to the power of [1 2 3]: , [3 4 1]

# %%
print("sine: ",np.sin(array1))
print("Natural logarithm: ",np.log(array1))
print("Base-10 logarithm: ",np.log10(array1))
print("Base-2 logarithm: ",np.log2(array1))
print("Exponential: ",np.exp(array1))
# Out:
# sine:  [0.84147098 0.90929743 0.14112001]
# Natural logarithm:  [0.         0.69314718 1.09861229]
# Base-10 logarithm:  [0.         0.30103    0.47712125]
# Base-2 logarithm:  [0.        1.        1.5849625]
# Exponential:  [ 2.71828183  7.3890561  20.08553692]

# %%
print("adding two numpy arrays {array1} and {array2} together:", array1+array2)
# Out:
# adding two numpy arrays {array1} and {array2} together: [4 4 4]

# %%
print(f"Adding two numpy arrays {array1} and {array2} together: {array1+array2}")
# Out:
# Adding two numpy arrays [1 2 3] and [3 2 1] together: [4 4 4]

# %%
people=['Greesy','Brandon','Emily','nic','Landon','Lilly','jeremy','eli','daisy','milo']
age=[21,22,19,13,11,20,14,17,19,34]
weight=[55,50,45,47,58,60,49,67,55,60]
height=[146,187,197,145,197,153,113,164,173,132]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(weight,height)
plt.title("Relationship between weight and height of patients")
plt.ylabel("height in Meters")
plt.xlabel("Weight of patients in Kgs")
plt.show()

# %%
people = ['sharini','greesy','teju','smily','pooji']
weight = [55,56,60,47,40]
height = [146,187,197,145,148]

# %%
plt.figure(figsize=(12,4))
plt.title("people's weight in kgs",fontsize=16,fontstyle='italic')
plt.bar(x=people,height=weight, width=0.6,color='orange',edgecolor='k',alpha=0.6)
plt.xlabel("people",fontsize=15)
plt.ylabel("weight (in kgs)",fontsize=15)
plt.show()

# %%
import numpy as np

plt.figure(figsize=(7,5))
plt.hist(weight,color='red',edgecolor='k',alpha=0.75,bins=5)
plt.title("Histogram of patient weight",fontsize=10)
plt.xlabel("weight in kgs",fontsize=15 )
plt.show()
